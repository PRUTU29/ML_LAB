# %% [markdown]
# <a href="https://colab.research.google.com/github/PRUTU29/ML_LAB/blob/main/lab10b/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing reqired libarires
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#import or laoding the dataset
dataset = pd.read_csv('wine.csv')

#distributing the dataset into two componets as X and Y
X=dataset.iloc[:,0:13].values
y=dataset.iloc[:,13].values

#splitting the X and Y into the
#training set and testing set
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.2,random_state=0)

#performing preprcosseing part-fitting standard scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
